# %% [markdown]
# # Моделирование движения тела, брошенного под углом к горизонту

# %% [markdown]
# # Используемые библиотеки
# * numpy --> Используется для математических операций над входными данными и вычисления результатов
# * matplotlib --> Используется для визуализации решения, построения графиков и т.д.
# * math --> Используется для математических операций над входными данными и вычисления результатов

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

from matplotlib import animation
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

# %% [markdown]
# На вход программе подаётся начальная скорость тела - **V0** и угол, под которым его бросают - **a**, в градусах

# %%
V0 = 10
a = 85

# %% [markdown]
# Результатом выполнения программы являются:
# * Траектория полёта тела
# * Дальность полёта тела
# * Максимальная высота подъёма
# * Время полёта тела
#
# Также можно рассчитать:
# * Координату Х
# * Координату У
# * Скорость тела
#
# В заданный момент времени **t**

# %%
#Ускорение свободного падения
g = 9.8
print('Ускорение свободного падения: ' + str(g))
# перевод угла из градусов в радианы
a1 = a * math.pi / 180
print('\nНачальный угол в радианах: ' + str(a1))
# начальная скорость по оси У
V0y = V0 * math.sin(a1)
print('\nНачальная скорость по У: ' + str(V0y))
# начальная скорость по Х
V0x = V0 * math.cos(a1)
print('\nНачальная скорость по Х: ' + str(V0x))
# Время полёта тела
t = 2 * V0y / g
print('\nВремя полёта: ' + str(t))
# Максимальная высота подъёма тела
H = V0y ** 2 / 2 / g
print('\nМаксимальная высота подъёма: ' + str(H))
# Дальность полёта тела
S = V0x * t
print('\nДальность полёта: ' + str(S))
# Out:
# Ускорение свободного падения: 9.8
#
# Начальный угол в радианах: 1.4835298641951802
#
# Начальная скорость по У: 9.961946980917455
#
# Начальная скорость по Х: 0.8715574274765814
#
# Время полёта: 2.0330504042688684
#
# Максимальная высота подъёма: 5.063285084214816
#
# Дальность полёта: 1.7719201802747988

# %% [markdown]
# Подготовим данные для визуализации

# %%
b = - 4 * H / S ** 2
c = 2 * H / S - b * S / 2
f = lambda t: b * t ** 2 + c * t
print(str(b) + 't^2 + ' + str(c) + 't')
x = np.linspace(0, S, 100)
lim = max(H, S)
# Out:
# -6.450658686549138t^2 + 11.430052302761347t

# %% [markdown]
# Визуализируем данные

# %%
fig = plt.figure(figsize=(10, 10))
plt.plot(x, f(x), color='black', linestyle='--')
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)
plt.xlim([0, lim + 1])
plt.ylim([0, lim + 1])
plt.grid()
plt.show()
# Out:
# <div id='07b512ef-340b-4e4d-927e-5d917d1f7d0b'></div>

# %%
fig = plt.figure(figsize=(10, 10))
plt.plot(x, f(x), color='black', linestyle='--')
plt.xlabel('X', fontsize=12)
plt.ylabel('Y', fontsize=12)
plt.xlim([0, lim + 1])
plt.ylim([0, lim + 1])
plt.grid()
current_t = t / 2
current_x = V0x * current_t
current_y = V0y * current_t - g * current_t ** 2 / 2
plt.scatter(current_x, current_y, color='red')
plt.show()
print('t: ' + str(current_t))
print('\nКоордината Х: ' + str(current_x))
print('\nКоордината Y: ' + str(current_y))

print('\nСкорость: ' + str(math.sqrt(V0x ** 2 + (V0y - g * current_t) ** 2)))
# Out:
# t: 1.0165252021344342
#
# Координата Х: 0.8859600901373994
#
# Координата Y: 5.063285084214815
#
# Скорость: 0.8715574274765814
